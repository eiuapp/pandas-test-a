# %%
# https://blog.csdn.net/zhengzhoudaxuexujay/article/details/80136610
import pandas_datareader as pdr
alibaba = pdr.get_data_yahoo("BABA")
amazon = pdr.get_data_yahoo("AMZN")

# %%
alibaba.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2014-09-19  99.699997  89.949997  92.699997  93.889999  271879400  93.889999
# 2014-09-22  92.949997  89.500000  92.699997  89.889999   66657800  89.889999
# 2014-09-23  90.480003  86.620003  88.940002  87.169998   39009800  87.169998
# 2014-09-24  90.570000  87.220001  88.470001  90.570000   32088000  90.570000
# 2014-09-25  91.500000  88.500000  91.089996  88.919998   28598000  88.919998

# %%
alibaba.tail()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2019-02-19  171.149994  166.500000  166.979996  170.179993  12982300
# 2019-02-20  172.679993  170.610001  171.000000  170.710007  12454900
# 2019-02-21  171.779999  169.800003  171.000000  171.660004   8434800
# 2019-02-22  177.020004  172.520004  172.800003  176.919998  16175600
# 2019-02-25  183.720001  180.729996  181.259995  183.250000  22685200
#
#              Adj Close
# Date
# 2019-02-19  170.179993
# 2019-02-20  170.710007
# 2019-02-21  171.660004
# 2019-02-22  176.919998
# 2019-02-25  183.250000

# %%
alibaba.shape
# Out:
# (1115, 6)

# %%
alibaba['Adj Close'].plot(legend=True)

# %%
alibaba['Volume'].plot(legend=True)

# %%
alibaba['Adj Close'].plot(legend=True)
amazon['Adj Close'].plot(legend=True)

# %%
alibaba['high-low'] = alibaba['High'] - alibaba['Low']
alibaba['high-low'].plot(legend=True)

# %%
alibaba['daily-return'] = alibaba['Adj Close'].pct_change()
alibaba['daily-return'].plot(figsize=(20,4),  marker='o')

# %%
alibaba['daily-return'].plot(kind='hist')

# %%
sns.distplot(alibaba['daily-return'].dropna(), bins=100, color='purple')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-162a93ae78ce> in <module>
# ----> 1 sns.distplot(alibaba['daily-return'].dropna(), bins=100, color='purple')
#
# NameError: name 'sns' is not defined
